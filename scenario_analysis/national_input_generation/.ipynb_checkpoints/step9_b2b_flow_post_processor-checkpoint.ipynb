# %%
# set environment and import packages
import os
from pandas import read_csv
import pandas as pd
import geopandas as gps
import matplotlib.pyplot as plt
import seaborn as sns
from os import listdir
import constants as c
import warnings
import numpy as np

warnings.filterwarnings("ignore")

os.chdir('/Users/xiaodanxu/Documents/SynthFirm.nosync')

# %%
sctg_group_lookup = read_csv(c.param_dir + c.sctg_group_lookup_file, sep = ',')
mesozone_lookup = read_csv(c.param_dir + c.mesozone_id_lookup_file, sep = ',')

truck_mode = ['For-hire Truck', 'Private Truck']
# max_ton_lookup = {'sctg1': 218.327, 'sctg2': 51.13091, 'sctg3': 94.56035, 'sctg4': 4.4861, 'sctg5': 51.64694}

# %%
combined_modeled_OD = None
mode_choide_by_commodity = None
combined_truck_output = None
for sctg in c.list_of_sctg_group:
    print(sctg)
#     if sctg != 'sctg5':
#         continue
    b2b_dir = c.output_dir + sctg
    list_of_b2b_files = listdir(b2b_dir)
    if sctg == 'sctg4':
        chunk_of_b2b_files = np.array_split(list_of_b2b_files, 50)
    elif sctg == 'sctg5':
        chunk_of_b2b_files = [list_of_b2b_files]
    else:
        chunk_of_b2b_files = np.array_split(list_of_b2b_files, 50)
    iterator = 0
#     cut_off_point = max_ton_lookup[sctg] # shipment capacity for this shipment
    for chunk in chunk_of_b2b_files:
        if len(chunk) == 0:
            continue
#         if file == '.DS_Store':
#             continue
#         if iterator%10 == 0:
        print(iterator)
        filelist = [file for file in chunk if (file.startswith('reassigned') & (file.endswith('.zip')))]
        modeled_OD_by_sctg = pd.concat([read_csv(b2b_dir  + '/' + f, low_memory=False) for f in filelist ])
#         modeled_OD_by_sctg = read_csv(b2b_dir + '/' + file, sep = ',')
#         print(modeled_OD_by_sctg.columns)
        print('data loading finished...')
        print(modeled_OD_by_sctg.TruckLoad.sum()/1000)
        list_of_var = ['BuyerID', 'BuyerZone', 'BuyerNAICS', 'SellerID',
           'SellerZone', 'SellerNAICS', 'TruckLoad', 'SCTG_Group', 
           'shipment_id', 'orig_FAFID', 'dest_FAFID', 'mode_choice']
#         print(modeled_OD_by_sctg.head(5))
        
#         modeled_OD_by_sctg.loc[modeled_OD_by_sctg['BuyerZone'] == 2270, 'BuyerZone'] = 2158
#         modeled_OD_by_sctg.loc[modeled_OD_by_sctg['SellerZone'] == 2270, 'SellerZone'] = 2158
#         modeled_OD_by_sctg.loc[modeled_OD_by_sctg['BuyerZone'] == 46113, 'BuyerZone'] = 46102
#         modeled_OD_by_sctg.loc[modeled_OD_by_sctg['SellerZone'] == 46113, 'SellerZone'] = 46102
#         modeled_OD_by_sctg.loc[modeled_OD_by_sctg['BuyerZone'] == 51515, 'BuyerZone'] = 51019
#         modeled_OD_by_sctg.loc[modeled_OD_by_sctg['SellerZone'] == 51515, 'SellerZone'] = 51019
        
        truck_output = modeled_OD_by_sctg.loc[modeled_OD_by_sctg['mode_choice'].isin(truck_mode), list_of_var]
        int_var = ['BuyerID', 'BuyerZone', 'SellerID',
           'SellerZone', 'SCTG_Group', 
           'shipment_id', 'orig_FAFID', 'dest_FAFID']
        truck_output.loc[:, int_var] = truck_output.loc[:, int_var].astype(int)
        truck_path = c.output_dir + sctg + '_truck/'
# Check whether the specified path exists or not
        isExist = os.path.exists(truck_path)
        if not isExist:

           # Create a new directory because it does not exist
           os.makedirs(truck_path)
        truck_output.to_csv(truck_path + 'truck_only_OD_' + sctg + '_' + 
                            str(iterator) + '.zip', index = False)

        
        ## compute national shipment count and tonmile
        print('generate summary statistics...')
        modeled_OD_by_sctg['ShipmentLoad'] = modeled_OD_by_sctg['TruckLoad'] / 1000 # convert to thousand tons
        
        #print(cut_off_point)
#         modeled_OD_by_sctg.loc[modeled_OD_by_sctg['ShipmentLoad'] > cut_off_point, 'ShipmentLoad'] = cut_off_point
        modeled_OD_by_sctg['tmiles'] = modeled_OD_by_sctg['ShipmentLoad'] * 1000 * modeled_OD_by_sctg['Distance']
        modeled_OD_by_sctg = pd.merge(modeled_OD_by_sctg, mesozone_lookup, 
                                      left_on = ['SellerZone', 'orig_FAFID'], 
                                    right_on = ['MESOZONE', 'FAFID'], how = 'inner')
        modeled_OD_by_sctg = modeled_OD_by_sctg.rename(columns={"GEOID": "orig_GEOID",
                                                                "CBPZONE": "orig_CBPZONE", 
                                                                "MESOZONE":"orig_MESOZONE", 
                                                                "FAFNAME":"orig_FAFNAME"})
        modeled_OD_by_sctg = pd.merge(modeled_OD_by_sctg, mesozone_lookup, 
                                      left_on = ['BuyerZone', 'dest_FAFID'], 
                                    right_on = ['MESOZONE', 'FAFID'], how = 'inner')
        modeled_OD_by_sctg = modeled_OD_by_sctg.rename(columns={"GEOID": "dest_GEOID", 
                                                                "CBPZONE": "dest_CBPZONE", 
                                                                "MESOZONE":"dest_MESOZONE", 
                                                               "FAFNAME":"dest_FAFNAME"})    
        agg_OD_by_sctg = modeled_OD_by_sctg.groupby(["orig_FAFID", "orig_FAFNAME", "dest_FAFID", "dest_FAFNAME", "SCTG_Group", 'mode_choice'])[['tmiles', 'ShipmentLoad']].sum()        
        agg_OD_by_sctg = agg_OD_by_sctg.reset_index()
        agg_count_by_sctg = modeled_OD_by_sctg.groupby(["orig_FAFID", "orig_FAFNAME", "dest_FAFID", "dest_FAFNAME", "SCTG_Group", 'mode_choice'])[['shipment_id']].count() 
        agg_count_by_sctg = agg_count_by_sctg.reset_index()
        agg_OD_by_sctg = pd.merge(agg_OD_by_sctg, agg_count_by_sctg, 
                                  on = ["orig_FAFID", "orig_FAFNAME", "dest_FAFID", "dest_FAFNAME", "SCTG_Group", 'mode_choice'],
                                  how = 'left')
        agg_OD_by_sctg = agg_OD_by_sctg.rename(columns={"shipment_id": "count"})
        agg_OD_by_sctg.loc[:, 'SCTG_Name'] = c.sctg_def[sctg]
        agg_OD_by_sctg.loc[:, 'chunk_id'] = iterator
        print(agg_OD_by_sctg.ShipmentLoad.sum())
        combined_modeled_OD = pd.concat([combined_modeled_OD, agg_OD_by_sctg], sort = False)
        iterator += 1 
#         break        
#     break
#     combined_truck_output.to_csv(c.input_dir + 'truck_only_OD_' + sctg + '.csv', index = False)
# combined_modeled_OD = pd.merge(combined_modeled_OD, sctg_group_definition, on = ['SCTG_Group'], how = 'left')
combined_modeled_OD.head(10)
# Out:
# sctg1
# 0
# data loading finished...
# 206345.7829197968
# generate summary statistics...
# 206345.78291979677
# 1
# data loading finished...
# 205651.07455540827
# generate summary statistics...
# 205651.0745554077
# 2
# data loading finished...
# 205844.3450153568
# generate summary statistics...
# 205844.3450153568
# 3
# data loading finished...
# 206540.3271471272
# generate summary statistics...
# 206540.3271471277
# 4
# data loading finished...
# 205414.4442640156
# generate summary statistics...
# 205414.4442640154
# 5
# data loading finished...
# 205353.24825376502
# generate summary statistics...
# 205353.24825376496
# 6
# data loading finished...
# 206906.09361816145
# generate summary statistics...
# 206906.093618163
# 7
# data loading finished...
# 179863.61498005153
# generate summary statistics...
# 179863.6149800517
# 8
# data loading finished...
# 205575.08952925057
# generate summary statistics...
# 205575.08952925244
# 9
# data loading finished...
# 207131.99622079823
# generate summary statistics...
# 207131.99622079782
# 10
# data loading finished...
# 205508.6655761115
# generate summary statistics...
# 205508.66557611237
# 11
# data loading finished...
# 205415.8380620574
# generate summary statistics...
# 205415.83806205727
# 12
# data loading finished...
# 214288.26030591244
# generate summary statistics...
# 214288.2603059124
# 13
# data loading finished...
# 230405.17253493384
# generate summary statistics...
# 230405.17253493378
# 14
# data loading finished...
# 230102.58526936013
# generate summary statistics...
# 230102.58526935958
# 15
# data loading finished...
# 214438.74767958777
# generate summary statistics...
# 214438.74767958774
# 16
# data loading finished...
# 219547.7208108343
# generate summary statistics...
# 219547.72081083467
# 17
# data loading finished...
# 1078185.9434244232
# generate summary statistics...
# 1078185.9434244265
# 18
# data loading finished...
# 209568.85696729406
# generate summary statistics...
# 209568.8569672941
# 19
# data loading finished...
# 217451.60299078588
# generate summary statistics...
# 217451.60299078646
# 20
# data loading finished...
# 221397.36359530478
# generate summary statistics...
# 221397.36359530466
# 21
# data loading finished...
# 209931.88173803547
# generate summary statistics...
# 209931.88173803617
# 22
# data loading finished...
# 237486.78630723967
# generate summary statistics...
# 237486.78630723932
# 23
# data loading finished...
# 225317.00018864806
# generate summary statistics...
# 225317.00018864812
# 24
# data loading finished...
# 197642.5610643042
# generate summary statistics...
# 197642.5610643039
# 25
# data loading finished...
# 231511.29908686227
# generate summary statistics...
# 231511.29908686268
# 26
# data loading finished...
# 197372.38148469804
# generate summary statistics...
# 197372.38148469862
# 27
# data loading finished...
# 222466.57161838427
# generate summary statistics...
# 222466.57161838416
# 28
# data loading finished...
# 221215.58162227427
# generate summary statistics...
# 221215.5816222739
# 29
# data loading finished...
# 206454.0624508394
# generate summary statistics...
# 206454.06245083944
# 30
# data loading finished...
# 206875.42655568945
# generate summary statistics...
# 206875.42655568963
# 31
# data loading finished...
# 213625.70889737344
# generate summary statistics...
# 213625.708897373
# 32
# data loading finished...
# 228890.34973697417
# generate summary statistics...
# 228890.3497369729
# 33
# data loading finished...
# 206872.89092534583
# generate summary statistics...
# 206872.89092534588
# 34
# data loading finished...
# 206142.74141325496
# generate summary statistics...
# 206142.74141325545
# 35
# data loading finished...
# 688650.1837315093
# generate summary statistics...
# 688650.1837315143
# 36
# data loading finished...
# 207529.70866302183
# generate summary statistics...
# 207529.7086630212
# 37
# data loading finished...
# 205422.35340763803
# generate summary statistics...
# 205422.3534076385
# 38
# data loading finished...
# 205581.3181112246
# generate summary statistics...
# 205581.3181112252
# 39
# data loading finished...
# 206200.12799250637
# generate summary statistics...
# 206200.127992506
# 40
# data loading finished...
# 205863.75458893934
# generate summary statistics...
# 205863.7545889393
# 41
# data loading finished...
# 205510.23944624056
# generate summary statistics...
# 205510.23944624088
# 42
# data loading finished...
# 189784.6407374294
# generate summary statistics...
# 189784.6407374292
# 43
# data loading finished...
# 205520.36753875093
# generate summary statistics...
# 205520.3675387518
# 44
# data loading finished...
# 205429.71181467673
# generate summary statistics...
# 205429.7118146768
# 45
# data loading finished...
# 198698.2521656236
# generate summary statistics...
# 198698.25216562342
# 46
# data loading finished...
# 180217.36311430353
# generate summary statistics...
# 180217.36311430426
# 47
# data loading finished...
# 179918.56458114626
# generate summary statistics...
# 179918.56458114658
# 48
# data loading finished...
# 179838.11842407056
# generate summary statistics...
# 179838.11842406954
# 49
# data loading finished...
# 171183.67834826958
# generate summary statistics...
# 171183.6783482695
# sctg2
# 0
# data loading finished...
# 77422.98238652544
# generate summary statistics...
# 77422.98238652562
# 1
# data loading finished...
# 55280.61708425301
# generate summary statistics...
# 55280.617084253034
# 2
# data loading finished...
# 51361.97381293864
# generate summary statistics...
# 51361.97381293859
# 3
# data loading finished...
# 27109.7848403632
# generate summary statistics...
# 27109.78484036321
# 4
# data loading finished...
# 41645.976351972
# generate summary statistics...
# 41645.97635197203
# 5
# data loading finished...
# 23040.062888196648
# generate summary statistics...
# 23040.062888196626
# 6
# data loading finished...
# 23585.27233709114
# generate summary statistics...
# 23585.27233709116
# 7
# data loading finished...
# 32439.719779796436
# generate summary statistics...
# 32439.719779796425
# 8
# data loading finished...
# 28626.04040323325
# generate summary statistics...
# 28626.040403233244
# 9
# data loading finished...
# 47740.56879008213
# generate summary statistics...
# 47740.56879008212
# 10
# data loading finished...
# 26026.53831567365
# generate summary statistics...
# 26026.53831567364
# 11
# data loading finished...
# 50453.75981966257
# generate summary statistics...
# 50453.75981966258
# 12
# data loading finished...
# 44319.33970871645
# generate summary statistics...
# 44319.339708716514
# 13
# data loading finished...
# 30759.319671195026
# generate summary statistics...
# 30759.319671195015
# 14
# data loading finished...
# 62216.294632059435
# generate summary statistics...
# 62216.29463205949
# 15
# data loading finished...
# 43534.60494399964
# generate summary statistics...
# 43534.60494399966
# 16
# data loading finished...
# 45069.21204579867
# generate summary statistics...
# 45069.212045798675
# 17
# data loading finished...
# 49372.23907969676
# generate summary statistics...
# 49372.23907969675
# 18
# data loading finished...
# 30760.371482215225
# generate summary statistics...
# 30760.371482215218
# 19
# data loading finished...
# 28936.148575436964
# generate summary statistics...
# 28936.14857543696
# 20
# data loading finished...
# 64126.772393716084
# generate summary statistics...
# 64126.772393716135
# 21
# data loading finished...
# 37101.90343277077
# generate summary statistics...
# 37101.903432770734
# 22
# data loading finished...
# 30759.730127633124
# generate summary statistics...
# 30759.730127633135
# 23
# data loading finished...
# 30756.02555194998
# generate summary statistics...
# 30756.025551949948
# 24
# data loading finished...
# 57440.44739670331
# generate summary statistics...
# 57440.44739670331
# 25
# data loading finished...
# 51206.88669189537
# generate summary statistics...
# 51206.88669189537
# 26
# data loading finished...
# 30759.75254702295
# generate summary statistics...
# 30759.752547022945
# 27
# data loading finished...
# 46744.28428325537
# generate summary statistics...
# 46744.28428325533
# 28
# data loading finished...
# 77735.13569912367
# generate summary statistics...
# 77735.13569912371
# 29
# data loading finished...
# 30917.404929032644
# generate summary statistics...
# 30917.4049290326
# 30
# data loading finished...
# 29902.64150336029
# generate summary statistics...
# 29902.641503360264
# 31
# data loading finished...
# 46262.1366060561
# generate summary statistics...
# 46262.13660605597
# 32
# data loading finished...
# 46151.12549427995
# generate summary statistics...
# 46151.125494279986
# 33
# data loading finished...
# 58402.9443148325
# generate summary statistics...
# 58402.944314832544
# 34
# data loading finished...
# 47468.72760732659
# generate summary statistics...
# 47468.7276073266
# 35
# data loading finished...
# 62594.78925759158
# generate summary statistics...
# 62594.78925759153
# 36
# data loading finished...
# 69191.83666775885
# generate summary statistics...
# 69191.83666775886
# 37
# data loading finished...
# 45559.33115419622
# generate summary statistics...
# 45559.33115419616
# 38
# data loading finished...
# 28427.687732373655
# generate summary statistics...
# 28427.687732373644
# 39
# data loading finished...
# 41613.326023667476
# generate summary statistics...
# 41613.3260236675
# 40
# data loading finished...
# 16122.826196137941
# generate summary statistics...
# 16122.826196137941
# 41
# data loading finished...
# 30255.728417673057
# generate summary statistics...
# 30255.728417673046
# 42
# data loading finished...
# 30306.907001915115
# generate summary statistics...
# 30306.90700191511
# 43
# data loading finished...
# 56030.34133879964
# generate summary statistics...
# 56030.34133879963
# 44
# data loading finished...
# 56000.576760270735
# generate summary statistics...
# 56000.576760270735
# 45
# data loading finished...
# 27648.034324105534
# generate summary statistics...
# 27648.034324105545
# 46
# data loading finished...
# 55816.51894721944
# generate summary statistics...
# 55816.5189472194
# 47
# data loading finished...
# 30093.61243309209
# generate summary statistics...
# 30093.612433092072
# 48
# data loading finished...
# 42758.11176259128
# generate summary statistics...
# 42758.11176259123
# 49
# data loading finished...
# 55995.80974143056
# generate summary statistics...
# 55995.80974143058
# sctg3
# 0
# data loading finished...
# 112302.3238714298
# generate summary statistics...
# 112302.32387142983
# 1
# data loading finished...
# 77860.94979576099
# generate summary statistics...
# 77860.94979576103
# 2
# data loading finished...
# 112301.62807775704
# generate summary statistics...
# 112301.62807775715
# 3
# data loading finished...
# 95082.09927698987
# generate summary statistics...
# 95082.09927699066
# 4
# data loading finished...
# 110415.73962582831
# generate summary statistics...
# 110415.73962582849
# 5
# data loading finished...
# 95885.90357816868
# generate summary statistics...
# 95885.90357816863
# 6
# data loading finished...
# 100163.2625167862
# generate summary statistics...
# 100163.26251678623
# 7
# data loading finished...
# 118062.84678483669
# generate summary statistics...
# 118062.84678483676
# 8
# data loading finished...
# 96986.87369486623
# generate summary statistics...
# 96986.87369486637
# 9
# data loading finished...
# 123967.34609040036
# generate summary statistics...
# 123967.34609040116
# 10
# data loading finished...
# 84065.05792047609
# generate summary statistics...
# 84065.05792047633
# 11
# data loading finished...
# 94319.98754363811
# generate summary statistics...
# 94319.98754363813
# 12
# data loading finished...
# 47423.96910017947
# generate summary statistics...
# 47423.96910017948
# 13
# data loading finished...
# 96958.95088270113
# generate summary statistics...
# 96958.95088270117
# 14
# data loading finished...
# 97586.52289177176
# generate summary statistics...
# 97586.5228917719
# 15
# data loading finished...
# 44626.64925530533
# generate summary statistics...
# 44626.64925530541
# 16
# data loading finished...
# 89881.16460568184
# generate summary statistics...
# 89881.16460568193
# 17
# data loading finished...
# 93854.80144772817
# generate summary statistics...
# 93854.8014477281
# 18
# data loading finished...
# 96891.17417154477
# generate summary statistics...
# 96891.17417154487
# 19
# data loading finished...
# 54672.27494059193
# generate summary statistics...
# 54672.27494059194
# 20
# data loading finished...
# 100857.99378440085
# generate summary statistics...
# 100857.9937844007
# 21
# data loading finished...
# 84756.52247813476
# generate summary statistics...
# 84756.5224781348
# 22
# data loading finished...
# 39990.29677646393
# generate summary statistics...
# 39990.29677646388
# 23
# data loading finished...
# 81518.8361566157
# generate summary statistics...
# 81518.8361566156
# 24
# data loading finished...
# 107122.2613817121
# generate summary statistics...
# 107122.2613817122
# 25
# data loading finished...
# 65366.729302645464
# generate summary statistics...
# 65366.7293026455
# 26
# data loading finished...
# 123932.2234778702
# generate summary statistics...
# 123932.22347787012
# 27
# data loading finished...
# 95493.15246276275
# generate summary statistics...
# 95493.1524627629
# 28
# data loading finished...
# 131956.51928433616
# generate summary statistics...
# 131956.51928433622
# 29
# data loading finished...
# 108452.03141256253
# generate summary statistics...
# 108452.03141256254
# 30
# data loading finished...
# 110292.72228605716
# generate summary statistics...
# 110292.72228605731
# 31
# data loading finished...
# 71333.35457786485
# generate summary statistics...
# 71333.35457786503
# 32
# data loading finished...
# 111131.73804339296
# generate summary statistics...
# 111131.73804339312
# 33
# data loading finished...
# 111227.23860898042
# generate summary statistics...
# 111227.23860898058
# 34
# data loading finished...
# 50598.363534217046
# generate summary statistics...
# 50598.363534217
# 35
# data loading finished...
# 115614.82365238332
# generate summary statistics...
# 115614.82365238329
# 36
# data loading finished...
# 112877.38468681883
# generate summary statistics...
# 112877.38468681872
# 37
# data loading finished...
# 131840.52197227924
# generate summary statistics...
# 131840.5219722792
# 38
# data loading finished...
# 122577.819324841
# generate summary statistics...
# 122577.81932484085
# 39
# data loading finished...
# 110827.37200658741
# generate summary statistics...
# 110827.37200658733
# 40
# data loading finished...
# 93539.67768431152
# generate summary statistics...
# 93539.67768431178
# 41
# data loading finished...
# 124192.43419803794
# generate summary statistics...
# 124192.43419803833
# 42
# data loading finished...
# 108518.10112201572
# generate summary statistics...
# 108518.10112201603
# 43
# data loading finished...
# 97245.39296307319
# generate summary statistics...
# 97245.39296307333
# 44
# data loading finished...
# 99759.755549704
# generate summary statistics...
# 99759.75554970349
# 45
# data loading finished...
# 94288.87369799223
# generate summary statistics...
# 94288.8736979921
# 46
# data loading finished...
# 93585.08407585834
# generate summary statistics...
# 93585.08407585825
# 47
# data loading finished...
# 95313.63142978649
# generate summary statistics...
# 95313.63142978674
# 48
# data loading finished...
# 96298.10741290194
# generate summary statistics...
# 96298.10741290181
# 49
# data loading finished...
# 93584.22080062059
# generate summary statistics...
# 93584.22080062047
# sctg4
# 0
# data loading finished...
# 38898.73244740269
# generate summary statistics...
# 38898.73244740247
# 1
# data loading finished...
# 34955.6583868161
# generate summary statistics...
# 34955.658386816765
# 2
# data loading finished...
# 62331.045146321325
# generate summary statistics...
# 62331.04514632159
# 3
# data loading finished...
# 42809.77976144543
# generate summary statistics...
# 42809.77976144504
# 4
# data loading finished...
# 15718.591940580814
# generate summary statistics...
# 15718.591940580898
# 5
# data loading finished...
# 21822.80886837317
# generate summary statistics...
# 21822.808868373257
# 6
# data loading finished...
# 56731.03626568423
# generate summary statistics...
# 56731.03626568359
# 7
# data loading finished...
# 34223.364606611394
# generate summary statistics...
# 34223.36460661153
# 8
# data loading finished...
# 28214.876430143446
# generate summary statistics...
# 28214.87643014342
# 9
# data loading finished...
# 72601.68502205695
# generate summary statistics...
# 72601.6850220568
# 10
# data loading finished...
# 47987.103387297015
# generate summary statistics...
# 47987.10338729652
# 11
# data loading finished...
# 77396.4302035806
# generate summary statistics...
# 77396.43020358017
# 12
# data loading finished...
# 36696.2429582814
# generate summary statistics...
# 36696.242958281226
# 13
# data loading finished...
# 23325.872663470716
# generate summary statistics...
# 23325.872663470465
# 14
# data loading finished...
# 28276.08099199349
# generate summary statistics...
# 28276.080991993484
# 15
# data loading finished...
# 12541.821163840283
# generate summary statistics...
# 12541.821163840203
# 16
# data loading finished...
# 45835.54737149858
# generate summary statistics...
# 45835.54737149872
# 17
# data loading finished...
# 74775.47015772531
# generate summary statistics...
# 74775.47015772545
# 18
# data loading finished...
# 22651.543985269233
# generate summary statistics...
# 22651.543985269243
# 19
# data loading finished...
# 24320.183435465366
# generate summary statistics...
# 24320.18343546523
# 20
# data loading finished...
# 72168.67655152499
# generate summary statistics...
# 72168.67655152641
# 21
# data loading finished...
# 39234.15839229044
# generate summary statistics...
# 39234.158392289886
# 22
# data loading finished...
# 17246.10821520739
# generate summary statistics...
# 17246.10821520767
# 23
# data loading finished...
# 48003.55146082256
# generate summary statistics...
# 48003.5514608224
# 24
# data loading finished...
# 17973.903771312565
# generate summary statistics...
# 17973.90377131287
# 25
# data loading finished...
# 36186.615246876485
# generate summary statistics...
# 36186.61524687697
# 26
# data loading finished...
# 75702.3383081759
# generate summary statistics...
# 75702.33830817629
# 27
# data loading finished...
# 34567.602562866006
# generate summary statistics...
# 34567.60256286585
# 28
# data loading finished...
# 20518.870530904293
# generate summary statistics...
# 20518.870530904347
# 29
# data loading finished...
# 89626.08641306516
# generate summary statistics...
# 89626.08641306635
# 30
# data loading finished...
# 76006.94858902958
# generate summary statistics...
# 76006.94858902955
# 31
# data loading finished...
# 11669.456310826889
# generate summary statistics...
# 11669.456310826905
# 32
# data loading finished...
# 70200.19810825272
# generate summary statistics...
# 70200.19810825243
# 33
# data loading finished...
# 57639.59646762717
# generate summary statistics...
# 57639.59646762663
# 34
# data loading finished...
# 37709.9852068842
# generate summary statistics...
# 37709.9852068842
# 35
# data loading finished...
# 87080.27400117579
# generate summary statistics...
# 87080.2740011765
# 36
# data loading finished...
# 51768.41148288713
# generate summary statistics...
# 51768.41148288653
# 37
# data loading finished...
# 60645.91461708353
# generate summary statistics...
# 60645.91461708404
# 38
# data loading finished...
# 63501.04126649952
# generate summary statistics...
# 63501.041266499866
# 39
# data loading finished...
# 55108.737228635786
# generate summary statistics...
# 55108.737228635604
# 40
# data loading finished...
# 19909.82539969298
# generate summary statistics...
# 19909.82539969294
# 41
# data loading finished...
# 83508.31128362333
# generate summary statistics...
# 83508.3112836227
# 42
# data loading finished...
# 57537.609595273585
# generate summary statistics...
# 57537.60959527362
# 43
# data loading finished...
# 51585.313155785596
# generate summary statistics...
# 51585.31315578595
# 44
# data loading finished...
# 68266.57876523887
# generate summary statistics...
# 68266.57876523914
# 45
# data loading finished...
# 63825.29657937361
# generate summary statistics...
# 63825.296579373855
# 46
# data loading finished...
# 36323.88602999339
# generate summary statistics...
# 36323.88602999323
# 47
# data loading finished...
# 41575.261853696036
# generate summary statistics...
# 41575.26185369576
# 48
# data loading finished...
# 74959.77967137034
# generate summary statistics...
# 74959.77967137036
# 49
# data loading finished...
# 17047.161241411388
# generate summary statistics...
# 17047.161241411413
# sctg5
# 0
# data loading finished...
# 936.7718105
# generate summary statistics...
# 936.7718104999999
#    orig_FAFID orig_FAFNAME  dest_FAFID dest_FAFNAME  SCTG_Group  \
# 0          11   Birmingham          11   Birmingham           1
# 1          11   Birmingham          11   Birmingham           1
# 2          11   Birmingham          11   Birmingham           1
# 3          11   Birmingham          12       Mobile           1
# 4          11   Birmingham          12       Mobile           1
# 5          11   Birmingham          12       Mobile           1
# 6          11   Birmingham          19   Rest of AL           1
# 7          11   Birmingham          19   Rest of AL           1
# 8          11   Birmingham          19   Rest of AL           1
# 9          11   Birmingham          50     Arkansas           1
#
#       mode_choice        tmiles  ShipmentLoad  count SCTG_Name  chunk_id
# 0  For-hire Truck  0.000000e+00    875.848695  33549      bulk         0
# 1   Private Truck  0.000000e+00    494.927188  18958      bulk         0
# 2        Rail/IMX  0.000000e+00     36.575218   1401      bulk         0
# 3  For-hire Truck  3.251163e+05      1.151792     43      bulk         0
# 4   Private Truck  4.507356e+04      0.159682      6      bulk         0
# 5        Rail/IMX  3.210103e+04      0.053153      2      bulk         0
# 6  For-hire Truck  6.460600e+07    503.240378  19277      bulk         0
# 7   Private Truck  1.531282e+07    119.277316   4569      bulk         0
# 8        Rail/IMX  4.297229e+06     31.352940   1201      bulk         0
# 9  For-hire Truck  1.061609e+07     22.613888   1045      bulk         0

# %%
combined_modeled_OD_agg = combined_modeled_OD.groupby(["orig_FAFID", "orig_FAFNAME", "dest_FAFID", \
                                                       "dest_FAFNAME", "SCTG_Group", 'SCTG_Name',
                                                       'mode_choice'])[['tmiles', 'ShipmentLoad', 'count']].sum()
combined_modeled_OD_agg = combined_modeled_OD_agg.reset_index()
combined_modeled_OD_agg.head(5)
# combined_modeled_OD_agg.loc[:, 'in_study_area'] = 0
# buffer = combined_modeled_OD_agg.loc[:, 'orig_FAFID'].isin(c.bay_area_region_code) | \
#         combined_modeled_OD_agg.loc[:, 'dest_FAFID'].isin(c.bay_area_region_code)
# combined_modeled_OD_agg.loc[buffer, 'in_study_area'] = 1

# combined_modeled_OD_agg.loc[:, 'outbound'] = 0
# combined_modeled_OD_agg.loc[combined_modeled_OD_agg.loc[:, 'orig_FAFID'].isin(c.region_code), 'outbound'] = 1

# combined_modeled_OD_agg.loc[:, 'inbound'] = 0
# combined_modeled_OD_agg.loc[combined_modeled_OD_agg.loc[:, 'dest_FAFID'].isin(c.region_code), 'inbound'] = 1

combined_modeled_OD_agg.loc[:, 'orig_FAFID'] = combined_modeled_OD_agg.loc[:, 'orig_FAFID'].astype(int)
combined_modeled_OD_agg.loc[:, 'dest_FAFID'] = combined_modeled_OD_agg.loc[:, 'dest_FAFID'].astype(int)
combined_modeled_OD_agg.loc[:, 'SCTG_Group'] = combined_modeled_OD_agg.loc[:, 'SCTG_Group'].astype(int)
combined_modeled_OD_agg.loc[:, 'Distance'] = combined_modeled_OD_agg.loc[:, 'tmiles'] / 1000 / combined_modeled_OD_agg.loc[:, 'ShipmentLoad']
combined_modeled_OD_agg.head(10)
# Out:
#    orig_FAFID orig_FAFNAME  dest_FAFID dest_FAFNAME  SCTG_Group    SCTG_Name  \
# 0          11   Birmingham          11   Birmingham           1         bulk
# 1          11   Birmingham          11   Birmingham           1         bulk
# 2          11   Birmingham          11   Birmingham           1         bulk
# 3          11   Birmingham          11   Birmingham           2    fuel_fert
# 4          11   Birmingham          11   Birmingham           2    fuel_fert
# 5          11   Birmingham          11   Birmingham           2    fuel_fert
# 6          11   Birmingham          11   Birmingham           2    fuel_fert
# 7          11   Birmingham          11   Birmingham           2    fuel_fert
# 8          11   Birmingham          11   Birmingham           3  interm_food
# 9          11   Birmingham          11   Birmingham           3  interm_food
#
#       mode_choice  tmiles  ShipmentLoad    count  Distance
# 0  For-hire Truck     0.0  36393.178417  1165822       0.0
# 1   Private Truck     0.0  18864.606876   594327       0.0
# 2        Rail/IMX     0.0   1533.144496    47953       0.0
# 3             Air     0.0      0.058062       25       0.0
# 4  For-hire Truck     0.0    639.902371    38773       0.0
# 5          Parcel     0.0      0.000010        1       0.0
# 6   Private Truck     0.0    703.734493    50206       0.0
# 7        Rail/IMX     0.0     27.630723     1060       0.0
# 8             Air     0.0      0.089807       60       0.0
# 9  For-hire Truck     0.0    601.067965    40620       0.0

# %%
combined_modeled_OD_agg.to_csv(c.output_dir + 'processed_b2b_flow_summary.csv', sep = ',')
